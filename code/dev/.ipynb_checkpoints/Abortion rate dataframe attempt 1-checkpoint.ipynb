# %%
# Imports and universal whatnots
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
# %matplotlib inline


path = '../../data'
files = glob.glob(os.path.join(path, '*'))
file = path+'/master_abortion_midwest.csv'
file_transposed = path+'/master_abortion_midwest_transposed.csv'

# %%
# Pandas setup
rate_list = ['1998Rate', '1999Rate', '2000Rate', '2001Rate', '2002Rate', '2003Rate', '2004Rate', '2005Rate', '2006Rate', '2007Rate', '2008Rate', '2009Rate', '2010Rate', '2011Rate', '2012Rate', '2013Rate']
count_list = ['1998Count', '1999Count', '2000Count', '2001Count', '2002Count', '2003Count', '2004Count', '2005Count', '2006Count', '2007Count', '2008Count', '2009Count', '2010Count', '2011Count', '2012Count', '2013Count']

abortion_df = pd.read_csv(file, index_col='state', sep=',')
transposed_df = pd.read_csv(file_transposed, sep=',')
rates_transposed = pd.read_csv('../../data/rates_transposed.csv', index_col = 'Unnamed: 0',sep=',')

# abortion_df = abortion_df.set_index([2])

rate_df = abortion_df[rate_list]
count_df = abortion_df[count_list]



# abortion_df.head(10)
# transposed_df.head(10)
rates_transposed.head(15)
# Out:
#       Illinois  Indiana  Iowa  Kentucky  Michigan  Minnesota  Missouri  Ohio  \
# 1998      18.0      9.0  10.0       8.0      13.0       14.0       8.0  15.0
# 1999      17.0      9.0  10.0       6.0      12.0       14.0       7.0  15.0
# 2000      17.0      9.0   9.0       5.0      12.0       13.0       7.0  16.0
# 2001      17.0      9.0   9.0       4.0      13.0       14.0       6.0  15.0
# 2002      17.0      8.0  10.0       4.0      14.0       13.0       7.0  15.0
# 2003      16.0      9.0  10.0       4.0      14.0       13.0       7.0  15.0
# 2004      16.0      8.0  10.0      64.0      12.0       13.0       7.0  14.0
# 2005      16.0      8.0  10.0       4.0      12.0       12.0       7.0  15.0
# 2006      17.3      8.2  11.5       4.5      12.4       13.2       6.3  14.2
# 2007      16.9      8.4  11.4       5.1      12.1       13.1       6.1  13.4
# 2008      17.8      8.6  11.2       5.0      13.0       12.3       6.3  13.0
# ...

# %%
rates_transposed.plot(kind='line')

# %%
# Out:
#                1998Rate  1999Rate  2000Rate  2001Rate  2002Rate  2003Rate  \
# state
# Illinois             18        17        17        17        17        16
# Indiana               9         9         9         9         8         9
# Iowa                 10        10         9         9        10        10
# Kentucky              8         6         5         4         4         4
# Michigan             13        12        12        13        14        14
# Minnesota            14        14        13        14        13        13
# Missouri              8         7         7         6         7         7
# Ohio                 15        15        16        15        15        15
# Wisconsin            10        10        10         9         9         9
# United States        17        17        16        16        16        16
#
#                2004Rate  2005Rate  2006Rate  2007Rate  2008Rate  2009Rate  \
# state
# ...

# %%
rate_df['1998Rate'].hist(bins=6)

# %%
# plt.figure(1, figsize=(50,10))
# rate_df.hist()
# plt.subplot(2,10,6)
rate_df.plot(kind='line')

# %%
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-95-ee7fff8dcd38> in <module>()
# ----> 1 date = sns.load_dataset(file)
#
# /Users/James/anaconda/lib/python3.5/site-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     422                                   os.path.basename(full_path))
#     423         if not os.path.exists(cache_path):
# --> 424             urlretrieve(full_path, cache_path)
#     425         full_path = cache_path
#     426
#
# /Users/James/anaconda/lib/python3.5/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     186     url_type, path = splittype(url)
#     187
# --> 188     with contextlib.closing(urlopen(url, data)) as fp:
#     189         headers = fp.info()
#     190
#
# /Users/James/anaconda/lib/python3.5/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-97-300c357c9c09> in <module>()
#       1 # plotly
# ----> 2 import plotly.plotly as py
#       3 import plotly.graph_objs as go
#       4
#       5 N = 500
#
# ImportError: No module named 'plotly'
